# %%
file_info = {
    "air_conditioner_222_week_1_minutes.csv": {"type":"air condtioner","group":"cooling"},
    "air_conditioner_222_week_2_minutes.csv": {"type":"air condtioner","group":"cooling"},
    "air_conditioner_222_week_3_minutes.csv": {"type":"air condtioner","group":"cooling"},
    "air_purifier_293_week_1_minutes.csv": {"type":"air purifier","group":"other"},
    "air_purifier_293_week_2_minutes.csv": {"type":"air purifier","group":"other"},
    "air_purifier_293_week_3_minutes.csv": {"type":"air purifier","group":"other"},
    "3D_printer_29_week_1_minutes.csv": {"type":"3D printer","group":"multimedia"},
    "3D_printer_29_week_2_minutes.csv": {"type":"3D printer","group":"multimedia"},
    "3D_printer_29_week_3_minutes.csv": {"type":"3D printer","group":"multimedia"},
    "boiler_217_week_1_minutes.csv": {"type":"boiler","group":"kitchen"},
    "boiler_217_week_2_minutes.csv": {"type":"boiler","group":"kitchen"},
    "boiler_217_week_3_minutes.csv": {"type":"boiler","group":"kitchen"},
    "boiler_226_week_1_minutes.csv": {"type":"boiler","group":"kitchen"},
    "boiler_226_week_2_minutes.csv": {"type":"boiler","group":"kitchen"},
    "boiler_226_week_3_minutes.csv": {"type":"boiler","group":"kitchen"},
    "boiler_233_week_1_minutes.csv": {"type":"boiler","group":"kitchen"},
    "boiler_233_week_2_minutes.csv": {"type":"boiler","group":"kitchen"},
    "boiler_233_week_3_minutes.csv": {"type":"boiler","group":"kitchen"},
    "boiler_233_week_4_minutes.csv": {"type":"boiler","group":"kitchen"},
    "coffee_37_week_1_minutes.csv": {"type":"coffee","group":"kitchen"},
    "coffee_37_week_2_minutes.csv": {"type":"coffee","group":"kitchen"},
    "coffee_37_week_3_minutes.csv": {"type":"coffee","group":"kitchen"},
    "coffee_54_week_1_minutes.csv": {"type":"coffee","group":"kitchen"},
    "coffee_54_week_2_minutes.csv": {"type":"coffee","group":"kitchen"},
    "coffee_54_week_3_minutes.csv": {"type":"coffee","group":"kitchen"},
    "coffee_54_week_4_minutes.csv": {"type":"coffee","group":"kitchen"},
    "coffee_97_week_1_minutes.csv": {"type":"coffee","group":"kitchen"},
    "coffee_97_week_2_minutes.csv": {"type":"coffee","group":"kitchen"},
    "coffee_97_week_3_minutes.csv": {"type":"coffee","group":"kitchen"},
    "computer_44_week_1_minutes.csv": {"type":"computer","group":"multimedia"},
    "computer_44_week_2_minutes.csv": {"type":"computer","group":"multimedia"},
    "computer_44_week_3_minutes.csv": {"type":"computer","group":"multimedia"},
    "dehumidifier_310_week_1_minutes.csv": {"type":"dehumidifier","group":"other"},
    "dehumidifier_310_week_2_minutes.csv": {"type":"dehumidifier","group":"other"},
    "dehumidifier_310_week_3_minutes.csv": {"type":"dehumidifier","group":"other"},
    "dehumidifier_310_week_4_minutes.csv": {"type":"dehumidifier","group":"other"},
    "dehumidifier_322_week_1_minutes.csv": {"type":"dehumidifier","group":"other"},
    "dehumidifier_322_week_2_minutes.csv": {"type":"dehumidifier","group":"other"},
    "dehumidifier_322_week_3_minutes.csv": {"type":"dehumidifier","group":"other"},
    "dishwasher_53_week_1_minutes.csv": {"type":"dishwasher","group":"washing"},
    "dishwasher_53_week_2_minutes.csv": {"type":"dishwasher","group":"washing"},
    "dishwasher_53_week_3_minutes.csv": {"type":"dishwasher","group":"washing"},
    "dryer_219_week_1_minutes.csv": {"type":"dryer","group":"washing"},
    "dryer_219_week_2_minutes.csv": {"type":"dryer","group":"washing"},
    "dryer_219_week_3_minutes.csv": {"type":"dryer","group":"washing"},
    "fan_215_week_1_minutes.csv": {"type":"fan","group":"cooling"},
    "fan_215_week_2_minutes.csv": {"type":"fan","group":"cooling"},
    "fan_215_week_3_minutes.csv": {"type":"fan","group":"cooling"},
    "freezer_249_week_1_minutes.csv": {"type":"freezer","group":"kitchen"},
    "freezer_249_week_2_minutes.csv": {"type":"freezer","group":"kitchen"},
    "freezer_249_week_3_minutes.csv": {"type":"freezer","group":"kitchen"},
    "fridge_98_week_1_minutes.csv": {"type":"fridge","group":"kitchen"},
    "fridge_98_week_2_minutes.csv": {"type":"fridge","group":"kitchen"},
    "fridge_98_week_3_minutes.csv": {"type":"fridge","group":"kitchen"},
    "fridge_207_week_1_minutes.csv": {"type":"fridge","group":"kitchen"},
    "fridge_207_week_2_minutes.csv": {"type":"fridge","group":"kitchen"},
    "fridge_207_week_3_minutes.csv": {"type":"fridge","group":"kitchen"},
    "fridge_284_week_1_minutes.csv": {"type":"fridge","group":"kitchen"},
    "fridge_284_week_2_minutes.csv": {"type":"fridge","group":"kitchen"},
    "fridge_284_week_3_minutes.csv": {"type":"fridge","group":"kitchen"},
    "fridge_317_week_1_minutes.csv": {"type":"fridge","group":"kitchen"},
    "fridge_317_week_2_minutes.csv": {"type":"fridge","group":"kitchen"},
    "fridge_317_week_3_minutes.csv": {"type":"fridge","group":"kitchen"},
    "internet_router_131_week_1_minutes.csv": {"type":"internet router","group":"multimedia"},
    "internet_router_131_week_2_minutes.csv": {"type":"internet router","group":"multimedia"},
    "internet_router_131_week_3_minutes.csv": {"type":"internet router","group":"multimedia"},
    "internet_router_295_week_1_minutes.csv": {"type":"internet router","group":"multimedia"},
    "internet_router_295_week_2_minutes.csv": {"type":"internet router","group":"multimedia"},
    "internet_router_295_week_3_minutes.csv": {"type":"internet router","group":"multimedia"},
    "internet_router_295_week_4_minutes.csv": {"type":"internet router","group":"multimedia"},
    "laptop_64_week_1_minutes.csv": {"type":"laptop","group":"multimedia"},
    "laptop_64_week_2_minutes.csv": {"type":"laptop","group":"multimedia"},
    "laptop_64_week_3_minutes.csv": {"type":"laptop","group":"multimedia"},
    "laptop_289_week_1_minutes.csv": {"type":"laptop","group":"multimedia"},
    "laptop_289_week_2_minutes.csv": {"type":"laptop","group":"multimedia"},
    "laptop_289_week_3_minutes.csv": {"type":"laptop","group":"multimedia"},
    "laptop_289_week_4_minutes.csv": {"type":"laptop","group":"multimedia"},
    "micro_wave_oven_147_week_1_minutes.csv": {"type":"micro wave oven","group":"kitchen"},
    "micro_wave_oven_147_week_2_minutes.csv": {"type":"micro wave oven","group":"kitchen"},
    "micro_wave_oven_147_week_3_minutes.csv": {"type":"micro wave oven","group":"kitchen"},
    "micro_wave_oven_314_week_1_minutes.csv": {"type":"micro wave oven","group":"kitchen"},
    "micro_wave_oven_314_week_2_minutes.csv": {"type":"micro wave oven","group":"kitchen"},
    "micro_wave_oven_314_week_3_minutes.csv": {"type":"micro wave oven","group":"kitchen"},
    "phone_charger_282_week_1_minutes.csv": {"type":"phone charger","group":"multimedia"},
    "phone_charger_282_week_2_minutes.csv": {"type":"phone charger","group":"multimedia"},
    "phone_charger_282_week_3_minutes.csv": {"type":"phone charger","group":"multimedia"},
    "phone_charger_282_week_4_minutes.csv": {"type":"phone charger","group":"multimedia"},
    "printer_286_week_1_minutes.csv": {"type":"printer","group":"multimedia"},
    "printer_286_week_2_minutes.csv": {"type":"printer","group":"multimedia"},
    "printer_286_week_3_minutes.csv": {"type":"printer","group":"multimedia"},
    "radiator_309_week_1_minutes.csv": {"type":"radiator","group":"other"},
    "radiator_309_week_2_minutes.csv": {"type":"radiator","group":"other"},
    "radiator_309_week_3_minutes.csv": {"type":"radiator","group":"other"},
    "screen_146_week_1_minutes.csv": {"type":"screen","group":"multimedia"},
    "screen_146_week_2_minutes.csv": {"type":"screen","group":"multimedia"},
    "screen_146_week_3_minutes.csv": {"type":"screen","group":"multimedia"},
    "screen_302_week_1_minutes.csv": {"type":"screen","group":"multimedia"},
    "screen_302_week_2_minutes.csv": {"type":"screen","group":"multimedia"},
    "screen_302_week_3_minutes.csv": {"type":"screen","group":"multimedia"},
    "solar_panel_325_week_1_minutes.csv": {"type":"solar panel","group":"other"},
    "solar_panel_325_week_2_minutes.csv": {"type":"solar panel","group":"other"},
    "solar_panel_325_week_3_minutes.csv": {"type":"solar panel","group":"other"},
    "sound_system_252_week_1_minutes.csv": {"type":"sound system","group":"multimedia"},
    "sound_system_252_week_2_minutes.csv": {"type":"sound system","group":"multimedia"},
    "sound_system_252_week_3_minutes.csv": {"type":"sound system","group":"multimedia"},
    "sound_system_252_week_4_minutes.csv": {"type":"sound system","group":"multimedia"},
    "tv_290_week_1_minutes.csv": {"type":"tv","group":"multimedia"},
    "tv_290_week_2_minutes.csv": {"type":"tv","group":"multimedia"},
    "tv_290_week_3_minutes.csv": {"type":"tv","group":"multimedia"},
    "vacuum_236_week_1_minutes.csv": {"type":"vacuum","group":"other"},
    "vacuum_236_week_2_minutes.csv": {"type":"vacuum","group":"other"},
    "vacuum_236_week_3_minutes.csv": {"type":"vacuum","group":"other"},
    "vacuum_254_week_1_minutes.csv": {"type":"vacuum","group":"other"},
    "vacuum_254_week_2_minutes.csv": {"type":"vacuum","group":"other"},
    "vacuum_254_week_3_minutes.csv": {"type":"vacuum","group":"other"},
    "vacuum_254_week_4_minutes.csv": {"type":"vacuum","group":"other"},
    "washing_machine_32_week_1_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_32_week_2_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_32_week_3_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_52_week_1_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_52_week_2_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_52_week_3_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_135_week_1_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_135_week_2_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_135_week_3_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_157_week_1_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_157_week_2_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_157_week_3_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_218_week_1_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_218_week_2_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_218_week_3_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_218_week_4_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_343_week_1_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_343_week_2_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_343_week_3_minutes.csv": {"type":"washing machine","group":"washing"},
    "washing_machine_343_week_4_minutes.csv": {"type":"washing machine","group":"washing"},
}

# %%
def assign_type_and_group(file_name):
    if file_name in file_info:
        return file_info[file_name]["type"],file_info[file_name]["group"]
    else:
        return None, None

# %% [markdown]
# In our dataset, several electronic devices consume power. Each device is part of a category of devices :
# -multimedia = [computer, 3D_printer, internet_router, laptop, phone_charger, printer, screen, tv, sound_system],
# -kitchen = [boiler, coffee, freezer, fridge, micro_wave_oven],
# -cooling = [air_conditioner, fan],
# -other = [air_purifier, dehumidifier, radiator, solar_panel, vacuum],
#
#
# -boiler_233,
# coffee_54,
# dehumidifier_310
# internet_router_295
# laptop_289
# phone_charger_282
# sound_system_252
# vacuum_254
# washing_machine_218
# washing_machine_343
