# %%
import pandas as pd

df = pd.read_csv("household_power_consumption/3D_printer_29.csv")

week_one = df[259200:864000:60]
week_two = df[864000:1468800:60]
week_three=df[1468800:2073600:60]


week_one.to_csv('3D_printer_29_week_1_minutes.csv', index=False)
week_two.to_csv('3D_printer_29_week_2_minutes.csv', index=False)
week_three.to_csv('3D_printer_29_week_3_minutes.csv', index=False)


df = pd.read_csv("household_power_consumption/air_conditioner_222.csv")

week_one = df[385333:990133:60]
week_two = df[990133:1594933:60]
week_three=df[1594933:2199733:60]

week_one.to_csv('air_conditioner_222_week_1_minutes.csv', index=False)
week_two.to_csv('air_conditioner_222_week_2_minutes.csv', index=False)
week_three.to_csv('air_conditioner_222_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/air_purifier_293.csv")

week_one = df[339308:944108:60]
week_two = df[944108:1548908:60]
week_three=df[1548908:2153708:60]

week_one.to_csv('air_purifier_293_week_1_minutes.csv', index=False)
week_two.to_csv('air_purifier_293_week_2_minutes.csv', index=False)
week_three.to_csv('air_purifier_293_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/boiler_217.csv")

week_one = df[351967:956767:60]
week_two = df[956767:1561567:60]
week_three=df[1561567:2166367:60]

week_one.to_csv('boiler_217_week_1_minutes.csv', index=False)
week_two.to_csv('boiler_217_week_2_minutes.csv', index=False)
week_three.to_csv('boiler_217_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/boiler_226.csv")

week_one = df[325867:930667:60]
week_two = df[930667:1535467:60]
week_three=df[1535467:2140267:60]

week_one.to_csv('boiler_226_week_1_minutes.csv', index=False)
week_two.to_csv('boiler_226_week_2_minutes.csv', index=False)
week_three.to_csv('boiler_226_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/boiler_233.csv")

week_one = df[20952:625752:60]
week_two = df[625752:1230552:60]
week_three=df[1230552:1835352:60]
week_four=df[1835352:2440152:60]

week_one.to_csv('boiler_233_week_1_minutes.csv', index=False)
week_two.to_csv('boiler_233_week_2_minutes.csv', index=False)
week_three.to_csv('boiler_233_week_3_minutes.csv', index=False)
week_four.to_csv('boiler_233_week_4_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/coffee_37.csv")

week_one = df[452989:1057789:60]
week_two = df[1057789:1662589:60]
week_three=df[1662589:2267389:60]

week_one.to_csv('coffee_37_week_1_minutes.csv', index=False)
week_two.to_csv('coffee_37_week_2_minutes.csv', index=False)
week_three.to_csv('coffee_37_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/coffee_54.csv")

week_one = df[40083:644883:60]
week_two = df[644883:1249683:60]
week_three=df[1249683:1854483:60]
week_four=df[1854483:2459283:60]

week_one.to_csv('coffee_54_week_1_minutes.csv', index=False)
week_two.to_csv('coffee_54_week_2_minutes.csv', index=False)
week_three.to_csv('coffee_54_week_3_minutes.csv', index=False)
week_four.to_csv('coffee_54_week_4_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/computer_44.csv")

week_one = df[493516:1098316:60]
week_two = df[1098316:1703116:60]
week_three=df[1703116:2307916:60]

week_one.to_csv('computer_44_week_1_minutes.csv', index=False)
week_two.to_csv('computer_44_week_2_minutes.csv', index=False)
week_three.to_csv('computer_44_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/dehumidifier_310.csv")

week_one = df[40082:644882:60]
week_two = df[644882:1249682:60]
week_three=df[1249682:1854482:60]
week_four=df[1854482:2459282:60]

week_one.to_csv('dehumidifier_310_week_1_minutes.csv', index=False)
week_two.to_csv('dehumidifier_310_week_2_minutes.csv', index=False)
week_three.to_csv('dehumidifier_310_week_3_minutes.csv', index=False)
week_four.to_csv('dehumidifier_310_week_4_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/dehumidifier_322.csv")

week_one = df[426159:1030959:60]
week_two = df[1030959:1635759:60]
week_three=df[1635759:2240559:60]

week_one.to_csv('dehumidifier_322_week_1_minutes.csv', index=False)
week_two.to_csv('dehumidifier_322_week_2_minutes.csv', index=False)
week_three.to_csv('dehumidifier_322_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/dishwasher_53.csv")

week_one = df[601715:1206515:60]
week_two = df[1206515:1811315:60]
week_three=df[1811315:2416115:60]

week_one.to_csv('dishwasher_53_week_1_minutes.csv', index=False)
week_two.to_csv('dishwasher_53_week_2_minutes.csv', index=False)
week_three.to_csv('dishwasher_53_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/dryer_219.csv")

week_one = df[345600:950400:60]
week_two = df[950400:1555200:60]
week_three=df[1555200:2160000:60]

week_one.to_csv('dryer_219_week_1_minutes.csv', index=False)
week_two.to_csv('dryer_219_week_2_minutes.csv', index=False)
week_three.to_csv('dryer_219_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/fan_215.csv")

week_one = df[277592:882392:60]
week_two = df[882392:1487192:60]
week_three=df[1487192:2091992:60]

week_one.to_csv('fan_215_week_1_minutes.csv', index=False)
week_two.to_csv('fan_215_week_2_minutes.csv', index=False)
week_three.to_csv('fan_215_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/freezer_249.csv")

week_one = df[209171:813971:60]
week_two = df[813971:1418771:60]
week_three=df[1418771:2023571:60]

week_one.to_csv('freezer_249_week_1_minutes.csv', index=False)
week_two.to_csv('freezer_249_week_2_minutes.csv', index=False)
week_three.to_csv('freezer_249_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/fridge_98.csv")

week_one = df[259200:864000:60]
week_two = df[864000:1468800:60]
week_three=df[1468800:2073600:60]

week_one.to_csv('fridge_98_week_1_minutes.csv', index=False)
week_two.to_csv('fridge_98_week_2_minutes.csv', index=False)
week_three.to_csv('fridge_98_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/fridge_207.csv")

week_one = df[371875:976675:60]
week_two = df[976675:1581475:60]
week_three=df[1581475:2186275:60]

week_one.to_csv('fridge_207_week_1_minutes.csv', index=False)
week_two.to_csv('fridge_207_week_2_minutes.csv', index=False)
week_three.to_csv('fridge_207_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/fridge_284.csv")

week_one = df[257243:862043:60]
week_two = df[862043:1466843:60]
week_three=df[1466843:2071643:60]

week_one.to_csv('fridge_284_week_1_minutes.csv', index=False)
week_two.to_csv('fridge_284_week_2_minutes.csv', index=False)
week_three.to_csv('fridge_284_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/fridge_317.csv")

week_one = df[432000:1036800:60]
week_two = df[1036800:1641600:60]
week_three=df[1641600:2246400:60]

week_one.to_csv('fridge_317_week_1_minutes.csv', index=False)
week_two.to_csv('fridge_317_week_2_minutes.csv', index=False)
week_three.to_csv('fridge_317_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/internet_router_131.csv")

week_one = df[469710:1074510:60]
week_two = df[1074510:1679310:60]
week_three=df[1679310:2284110:60]

week_one.to_csv('internet_router_131_week_1_minutes.csv', index=False)
week_two.to_csv('internet_router_131_week_2_minutes.csv', index=False)
week_three.to_csv('internet_router_131_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/internet_router_295.csv")

week_one = df[145255:750055:60]
week_two = df[750055:1354855:60]
week_three=df[1354855:1959655:60]
week_four=df[1959655:2564455:60]

week_one.to_csv('internet_router_295_week_1_minutes.csv', index=False)
week_two.to_csv('internet_router_295_week_2_minutes.csv', index=False)
week_three.to_csv('internet_router_295_week_3_minutes.csv', index=False)
week_four.to_csv('internet_router_295_week_4_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/laptop_64.csv")

week_one = df[470392:1075192:60]
week_two = df[1075192:1679992:60]
week_three=df[1679992:2284792:60]

week_one.to_csv('laptop_64_week_1_minutes.csv', index=False)
week_two.to_csv('laptop_64_week_2_minutes.csv', index=False)
week_three.to_csv('laptop_64_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/laptop_289.csv")

week_one = df[151056:755856:60]
week_two = df[755856:1360656:60]
week_three=df[1360656:1965456:60]
week_four=df[1965456:2570256:60]

week_one.to_csv('laptop_289_week_1_minutes.csv', index=False)
week_two.to_csv('laptop_289_week_2_minutes.csv', index=False)
week_three.to_csv('laptop_289_week_3_minutes.csv', index=False)
week_four.to_csv('laptop_289_week_4_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/micro_wave_oven_147.csv")

week_one = df[552822:1157622:60]
week_two = df[1157622:1762422:60]
week_three=df[1762422:2367222:60]

week_one.to_csv('micro_wave_oven_147_week_1_minutes.csv', index=False)
week_two.to_csv('micro_wave_oven_147_week_2_minutes.csv', index=False)
week_three.to_csv('micro_wave_oven_147_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/micro_wave_oven_314.csv")

week_one = df[376834:981634:60]
week_two = df[981634:1586434:60]
week_three=df[1586434:2191234:60]

week_one.to_csv('micro_wave_oven_314_week_1_minutes.csv', index=False)
week_two.to_csv('micro_wave_oven_314_week_2_minutes.csv', index=False)
week_three.to_csv('micro_wave_oven_314_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/phone_charger_282.csv")

week_one = df[96892:701692:60]
week_two = df[701692:1306492:60]
week_three=df[1306492:1911292:60]
week_four=df[1911292:2516092:60]

week_one.to_csv('phone_charger_282_week_1_minutes.csv', index=False)
week_two.to_csv('phone_charger_282_week_2_minutes.csv', index=False)
week_three.to_csv('phone_charger_282_week_3_minutes.csv', index=False)
week_four.to_csv('phone_charger_282_week_4_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/printer_286.csv")

week_one = df[432000:1036800:60]
week_two = df[1036800:1641600:60]
week_three=df[1641600:2246400:60]

week_one.to_csv('printer_286_week_1_minutes.csv', index=False)
week_two.to_csv('printer_286_week_2_minutes.csv', index=False)
week_three.to_csv('printer_286_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/radiator_309.csv")

week_one = df[371875:976675:60]
week_two = df[976675:1581475:60]
week_three=df[1581475:2186275:60]

week_one.to_csv('radiator_309_week_1_minutes.csv', index=False)
week_two.to_csv('radiator_309_week_2_minutes.csv', index=False)
week_three.to_csv('radiator_309_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/screen_146.csv")

week_one = df[251104:855904:60]
week_two = df[855904:1460704:60]
week_three=df[1460704:2065504:60]

week_one.to_csv('screen_146_week_1_minutes.csv', index=False)
week_two.to_csv('screen_146_week_2_minutes.csv', index=False)
week_three.to_csv('screen_146_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/solar_panel_325.csv")

week_one = df[481897:1086697:60]
week_two = df[1086697:1691497:60]
week_three=df[1691497:2296297:60]

week_one.to_csv('solar_panel_325_week_1_minutes.csv', index=False)
week_two.to_csv('solar_panel_325_week_2_minutes.csv', index=False)
week_three.to_csv('solar_panel_325_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/sound_system_252.csv")

week_one = df[138017:742817:60]
week_two = df[742817:1347617:60]
week_three=df[1347617:1952417:60]
week_four=df[1952417:2557217:60]

week_one.to_csv('sound_system_252_week_1_minutes.csv', index=False)
week_two.to_csv('sound_system_252_week_2_minutes.csv', index=False)
week_three.to_csv('sound_system_252_week_3_minutes.csv', index=False)
week_four.to_csv('sound_system_252_week_4_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/tv_290.csv")

week_one = df[278481:883281:60]
week_two = df[883281:1488081:60]
week_three=df[1488081:2092881:60]

week_one.to_csv('tv_290_week_1_minutes.csv', index=False)
week_two.to_csv('tv_290_week_2_minutes.csv', index=False)
week_three.to_csv('tv_290_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/vacuum_236.csv")

week_one = df[222496:827296:60]
week_two = df[827296:1432096:60]
week_three=df[1432096:2036896:60]

week_one.to_csv('vacuum_236_week_1_minutes.csv', index=False)
week_two.to_csv('vacuum_236_week_2_minutes.csv', index=False)
week_three.to_csv('vacuum_236_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/vacuum_254.csv")

week_one = df[63597:668397:60]
week_two = df[668397:1273197:60]
week_three=df[1273197:1877997:60]
week_four=df[1877997:2482797:60]

week_one.to_csv('vacuum_254_week_1_minutes.csv', index=False)
week_two.to_csv('vacuum_254_week_2_minutes.csv', index=False)
week_three.to_csv('vacuum_254_week_3_minutes.csv', index=False)
week_four.to_csv('vacuum_254_week_4_minutes.csv', index=False)


df = pd.read_csv("household_power_consumption/washing_machine_32.csv")

week_one = df[564417:1169217:60]
week_two = df[1169217:1774017:60]
week_three=df[1774017:2378817:60]

week_one.to_csv('washing_machine_32_week_1_minutes.csv', index=False)
week_two.to_csv('washing_machine_32_week_2_minutes.csv', index=False)
week_three.to_csv('washing_machine_32_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/washing_machine_52.csv")

week_one = df[548941:1153741:60]
week_two = df[1153741:1758541:60]
week_three=df[1758541:2363341:60]

week_one.to_csv('washing_machine_52_week_1_minutes.csv', index=False)
week_two.to_csv('washing_machine_52_week_2_minutes.csv', index=False)
week_three.to_csv('washing_machine_52_week_3_minutes.csv', index=False)


df = pd.read_csv("household_power_consumption/washing_machine_135.csv")

week_one = df[259200:864000:60]
week_two = df[864000:1468800:60]
week_three=df[1468800:2073600:60]

week_one.to_csv('washing_machine_135_week_1_minutes.csv', index=False)
week_two.to_csv('washing_machine_135_week_2_minutes.csv', index=False)
week_three.to_csv('washing_machine_135_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/washing_machine_157.csv")

week_one = df[422966:1027766:60]
week_two = df[1027766:1632566:60]
week_three=df[1632566:2237366:60]

week_one.to_csv('washing_machine_157_week_1_minutes.csv', index=False)
week_two.to_csv('washing_machine_157_week_2_minutes.csv', index=False)
week_three.to_csv('washing_machine_157_week_3_minutes.csv', index=False)



df = pd.read_csv("household_power_consumption/washing_machine_218.csv")

week_one = df[108124:712924:60]
week_two = df[712924:1317724:60]
week_three=df[1317724:1922524:60]
week_four=df[1922524:2527324:60]

week_one.to_csv('washing_machine_218_week_1_minutes.csv', index=False)
week_two.to_csv('washing_machine_218_week_2_minutes.csv', index=False)
week_three.to_csv('washing_machine_218_week_3_minutes.csv', index=False)
week_four.to_csv('washing_machine_218_week_4_minutes.csv', index=False)


df = pd.read_csv("household_power_consumption/washing_machine_343.csv")

week_one = df[8011:612811:60]
week_two = df[612811:1217611:60]
week_three=df[1217611:1822411:60]
week_four=df[1822411:2427211:60]

week_one.to_csv('washing_machine_343_week_1_minutes.csv', index=False)
week_two.to_csv('washing_machine_343_week_2_minutes.csv', index=False)
week_three.to_csv('washing_machine_343_week_3_minutes.csv', index=False)
week_four.to_csv('washing_machine_343_week_4_minutes.csv', index=False)
