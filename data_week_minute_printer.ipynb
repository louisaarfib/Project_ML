# %%
import pandas as pd

def process_device(device_name, file_path, time_ranges):
    df = pd.read_csv(file_path,parse_dates=['timestamp'])
    for i, time_range in enumerate(time_ranges, start=1):
        start_idx, end_idx = time_range
        week_data = df[start_idx:end_idx]
        week_data_resampled = week_data.resample('1t', on='timestamp').power.sum()
        week_data_resampled.to_csv(f'csv_files_1week/{device_name}_week_{i}_minutes.csv', index=False)

devices = {
    "3D_printer_29": ("household_power_consumption/3D_printer_29.csv", [
        (259200, 864000),
        (864000, 1468800),
        (1468800, 2073600)
    ]),
    "air_conditioner_222": ("household_power_consumption/air_conditioner_222.csv", [
        (385333, 990133),
        (990133, 1594933),
        (1594933, 2199733)
    ]),
    "air_purifier_293": ("household_power_consumption/air_purifier_293.csv", [
        (339308,944108),
        (944108,1548908),
        (1548908,2153708)
    ]),
    "boiler_217": ("household_power_consumption/boiler_217.csv", [
        (351967, 956767, 60),
        (956767, 1561567, 60),
        (1561567, 2166367, 60)
    ]),
    "boiler_226": ("household_power_consumption/boiler_226.csv", [
        (325867, 930667, 60),
        (930667, 1535467, 60),
        (1535467, 2140267, 60)
    ]),
    "boiler_233": ("household_power_consumption/boiler_233.csv", [
        (20952, 625752, 60),
        (625752, 1230552, 60),
        (1230552, 1835352, 60),
        (1835352, 2440152, 60)
    ]),
    "coffee_37": ("household_power_consumption/coffee_37.csv", [
        (452989, 1057789, 60),
        (1057789, 1662589, 60),
        (1662589, 2267389, 60)
    ]),
    "coffee_54": ("household_power_consumption/coffee_54.csv", [
        (40083, 644883, 60),
        (644883, 1249683, 60),
        (1249683, 1854483, 60),
        (1854483, 2459283, 60)
    ]),
    #A CHECKER
    "coffee_97": ("household_power_consumption/coffee_97.csv", [
        (40083, 644883, 60),
        (644883, 1249683, 60),
        (1249683, 1854483, 60),
        (1854483, 2459283, 60)
    ]),
    "computer_44": ("household_power_consumption/computer_44.csv", [
        (493516, 1098316, 60),
        (1098316, 1703116, 60),
        (1703116, 2307916, 60)
    ]),
    "dehumidifier_310": ("household_power_consumption/dehumidifier_310.csv", [
        (40082, 644882, 60),
        (644882, 1249682, 60),
        (1249682, 1854482, 60),
        (1854482, 2459282, 60)
    ]),
    "dehumidifier_322": ("household_power_consumption/dehumidifier_322.csv", [
        (426159, 1030959, 60),
        (1030959, 1635759, 60),
        (1635759, 2240559, 60)
    ]),
    "dishwasher_53": ("household_power_consumption/dishwasher_53.csv", [
        (601715, 1206515, 60),
        (1206515, 1811315, 60),
        (1811315, 2416115, 60)
    ]),
    "dryer_219": ("household_power_consumption/dryer_219.csv", [
        (345600, 950400, 60),
        (950400, 1555200, 60),
        (1555200, 2160000, 60)
    ]),
    "fan_215": ("household_power_consumption/fan_215.csv", [
        (277592, 882392, 60),
        (882392, 1487192, 60),
        (1487192, 2091992, 60)
    ]),
    "freezer_249": ("household_power_consumption/freezer_249.csv", [
        (209171, 813971, 60),
        (813971, 1418771, 60),
        (1418771, 2023571, 60)
    ]),
    "fridge_98": ("household_power_consumption/fridge_98.csv", [
        (259200, 864000, 60),
        (864000, 1468800, 60),
        (1468800, 2073600, 60)
    ]),
    "fridge_207": ("household_power_consumption/fridge_207.csv", [
        (371875, 976675, 60),
        (976675, 1581475, 60),
        (1581475, 2186275, 60)
    ]),
    "fridge_284": ("household_power_consumption/fridge_284.csv", [
        (257243, 862043, 60),
        (862043, 1466843, 60),
        (1466843, 2071643, 60)
    ]),
    "fridge_317": ("household_power_consumption/fridge_317.csv", [
        (432000, 1036800, 60),
        (1036800, 1641600, 60),
        (1641600, 2246400, 60)
    ]),
    "internet_router_131": ("household_power_consumption/internet_router_131.csv", [
        (469710, 1074510, 60),
        (1074510, 1679310, 60),
        (1679310, 2284110, 60)
    ]),
    "internet_router_295": ("household_power_consumption/internet_router_295.csv", [
        (145255, 750055, 60),
        (750055, 1354855, 60),
        (1354855, 1959655, 60),
        (1959655, 2564455, 60)
    ]),
    "laptop_64": ("household_power_consumption/laptop_64.csv", [
        (470392, 1075192, 60),
        (1075192, 1679992, 60),
        (1679992, 2284792, 60)
    ]),
    "laptop_289": ("household_power_consumption/laptop_289.csv", [
        (151056, 755856, 60),
        (755856, 1360656, 60),
        (1360656, 1965456, 60),
        (1965456, 2570256, 60)
    ]),
    "micro_wave_oven_147": ("household_power_consumption/micro_wave_oven_147.csv", [
        (552822, 1157622, 60),
        (1157622, 1762422, 60),
        (1762422, 2367222, 60)
    ]),
    "micro_wave_oven_314": ("household_power_consumption/micro_wave_oven_314.csv", [
        (376834, 981634, 60),
        (981634, 1586434, 60),
        (1586434, 2191234, 60)
    ]),
    "phone_charger_282": ("household_power_consumption/phone_charger_282.csv", [
        (96892, 701692, 60),
        (701692, 1306492, 60),
        (1306492, 1911292, 60),
        (1911292, 2516092, 60)
    ]),
    "printer_286": ("household_power_consumption/printer_286.csv", [
        (432000, 1036800, 60),
        (1036800, 1641600, 60),
        (1641600, 2246400, 60)
    ]),
    "radiator_309": ("household_power_consumption/radiator_309.csv", [
        (371875, 976675, 60),
        (976675, 1581475, 60),
        (1581475, 2186275, 60)
    ]),
    "screen_146": ("household_power_consumption/screen_146.csv", [
        (251104, 855904, 60),
        (855904, 1460704, 60),
        (1460704, 2065504, 60)
    ]),
    #A CHECKER
    "screen_302": ("household_power_consumption/screen_302.csv", [
        (251104, 855904, 60),
        (855904, 1460704, 60),
        (1460704, 2065504, 60)
    ]),
    "solar_panel_325": ("household_power_consumption/solar_panel_325.csv", [
        (481897, 1086697, 60),
        (1086697, 1691497, 60),
        (1691497, 2296297, 60)
    ]),
    "sound_system_252": ("household_power_consumption/sound_system_252.csv", [
        (138017, 742817, 60),
        (742817, 1347617, 60),
        (1347617, 1952417, 60),
        (1952417, 2557217, 60)
    ]),
    "tv_290": ("household_power_consumption/tv_290.csv", [
        (278481, 883281, 60),
        (883281, 1488081, 60),
        (1488081, 2092881, 60)
    ]),
    "vacuum_236": ("household_power_consumption/vacuum_236.csv", [
        (222496, 827296, 60),
        (827296, 1432096, 60),
        (1432096, 2036896, 60)
    ]),
    "vacuum_254": ("household_power_consumption/vacuum_254.csv", [
        (63597, 668397, 60),
        (668397, 1273197, 60),
        (1273197, 1877997, 60),
        (1877997, 2482797, 60)
    ]),
    "washing_machine_32": ("household_power_consumption/washing_machine_32.csv", [
        (564417, 1169217, 60),
        (1169217, 1774017, 60),
        (1774017, 2378817, 60)
    ]),
    "washing_machine_52": ("household_power_consumption/washing_machine_52.csv", [
        (548941, 1153741, 60),
        (1153741, 1758541, 60),
        (1758541, 2363341, 60)
    ]),
    "washing_machine_135": ("household_power_consumption/washing_machine_135.csv", [
        (259200, 864000, 60),
        (864000, 1468800, 60),
        (1468800, 2073600, 60)
    ]),
    "washing_machine_157": ("household_power_consumption/washing_machine_157.csv", [
        (422966, 1027766, 60),
        (1027766, 1632566, 60),
        (1632566, 2237366, 60)
    ]),
    "washing_machine_218": ("household_power_consumption/washing_machine_218.csv", [
        (108124, 712924, 60),
        (712924, 1317724, 60),
        (1317724, 1922524, 60),
        (1922524, 2527324, 60)
    ]),
    "washing_machine_343": ("household_power_consumption/washing_machine_343.csv", [
        (8011, 612811, 60),
        (612811, 1217611, 60),
        (1217611, 1822411, 60),
        (1822411, 2427211, 60)
    ]),
}

for device, (file_path, time_ranges) in devices.items():
    process_device(device, file_path, time_ranges)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 26
#      11 devices = {
#      12     "3D_printer_29": ("household_power_consumption/3D_printer_29.csv", [
#      13         (259200, 864000),
#    (...)
#      22     # Add other devices here following the same structure
#      23 }
#      25 for device, (file_path, time_ranges) in devices.items():
# ---> 26     process_device(device, file_path, time_ranges)
#      28 df = pd.read_csv("household_power_consumption/3D_printer_29.csv",parse_dates=['timestamp'])
#      30 week_one = df[259200:864000]
#
# Cell In[3], line 4, in process_device(device_name, file_path, time_ranges)
#       3 def process_device(device_name, file_path, time_ranges):
# ----> 4     df = pd.read_csv(file_path,parse_dates=['timestamp'])
#       5     for i, time_range in enumerate(time_ranges, start=1):
#       6         start_idx, end_idx = time_range
#
# File c:\Users\louis\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\louis\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File c:\Users\louis\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1704, in TextFileReader.read(self, nrows)
#    1697 nrows = validate_integer("nrows", nrows)
#    1698 try:
#    1699     # error: "ParserBase" has no attribute "read"
#    1700     (
#    1701         index,
#    1702         columns,
#    1703         col_dict,
# -> 1704     ) = self._engine.read(  # type: ignore[attr-defined]
#    1705         nrows
#    1706     )
#    1707 except Exception:
#    1708     self.close()
#
# File c:\Users\louis\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:334, in CParserWrapper.read(self, nrows)
#     330         self._check_data_length(names, alldata)
#     332     data = {k: v for k, (i, v) in zip(names, data_tups)}
# --> 334     names, date_data = self._do_date_conversions(names, data)
#     335     index, column_names = self._make_index(date_data, alldata, names)
#     337 return index, column_names, date_data
#
# File c:\Users\louis\anaconda3\Lib\site-packages\pandas\io\parsers\base_parser.py:863, in ParserBase._do_date_conversions(self, names, data)
#     855 def _do_date_conversions(
#     856     self,
#     857     names: Sequence[Hashable] | Index,
#     858     data: Mapping[Hashable, ArrayLike] | DataFrame,
#     859 ) -> tuple[Sequence[Hashable] | Index, Mapping[Hashable, ArrayLike] | DataFrame]:
#     860     # returns data, columns
#     862     if self.parse_dates is not None:
# --> 863         data, names = _process_date_conversion(
#     864             data,
#     865             self._date_conv,
#     866             self.parse_dates,
#     867             self.index_col,
#     868             self.index_names,
#     869             names,
#     870             keep_date_col=self.keep_date_col,
#     871             dtype_backend=self.dtype_backend,
#     872         )
#     874     return names, data
#
# File c:\Users\louis\anaconda3\Lib\site-packages\pandas\io\parsers\base_parser.py:1257, in _process_date_conversion(data_dict, converter, parse_spec, index_col, index_names, columns, keep_date_col, dtype_backend)
#    1253             continue
#    1255     # Pyarrow engine returns Series which we need to convert to
#    1256     # numpy array before converter, its a no-op for other parsers
# -> 1257     data_dict[colspec] = converter(
#    1258         np.asarray(data_dict[colspec]), col=colspec
#    1259     )
#    1260 else:
#    1261     new_name, col, old_names = _try_convert_dates(
#    1262         converter, colspec, data_dict, orig_names
#    1263     )
#
# File c:\Users\louis\anaconda3\Lib\site-packages\pandas\io\parsers\base_parser.py:1133, in _make_date_converter.<locals>.converter(col, *date_cols)
#    1128 strs = parsing.concat_date_cols(date_cols)
#    1129 date_fmt = (
#    1130     date_format.get(col) if isinstance(date_format, dict) else date_format
#    1131 )
# -> 1133 result = tools.to_datetime(
#    1134     ensure_object(strs),
#    1135     format=date_fmt,
#    1136     utc=False,
#    1137     dayfirst=dayfirst,
#    1138     errors="ignore",
#    1139     cache=cache_dates,
#    1140 )
#    1141 if isinstance(result, DatetimeIndex):
#    1142     arr = result.to_numpy()
#
# File c:\Users\louis\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1082, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1080         result = _convert_and_box_cache(argc, cache_array)
#    1081     else:
# -> 1082         result = convert_listlike(argc, format)
#    1083 else:
#    1084     result = convert_listlike(np.array([arg]), format)[0]
#
# File c:\Users\louis\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File c:\Users\louis\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:485, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     481 """
#     482 Call array_strptime, with fallback behavior depending on 'errors'.
#     483 """
#     484 result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
# --> 485 if any(tz is not None for tz in timezones):
#     486     return _return_parsed_timezone_results(result, timezones, utc, name)
#     488 return _box_as_indexlike(result, utc=utc, name=name)
#
# File c:\Users\louis\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:485, in <genexpr>(.0)
#     481 """
#     482 Call array_strptime, with fallback behavior depending on 'errors'.
#     483 """
#     484 result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
# --> 485 if any(tz is not None for tz in timezones):
#     486     return _return_parsed_timezone_results(result, timezones, utc, name)
#     488 return _box_as_indexlike(result, utc=utc, name=name)
#
# KeyboardInterrupt:
